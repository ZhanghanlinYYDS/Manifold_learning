# %%
from LLE import LLE
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
data=np.loadtxt('../data/data/synthetic/Aggregation.txt')
# print("data=\n",data[:5,:])
x=data[:,1:]
y=data[:,0]
print("unique(y)=",np.unique(y))
print(x.shape)
cluster_num=len(np.unique(y))
ss_x=StandardScaler()
x=ss_x.fit_transform(x)

plt.figure(figsize=(5,5))
for i in np.unique(y):
    plt.scatter(x[y==i,0],x[y==i,1],s=20)
# Out:
# unique(y)= [1. 2. 3. 4. 5. 6. 7.]
# (788, 2)

# %%
YY=LLE(x,2,10,jump=False)
plt.figure(figsize=[5,5])
for i in np.unique(y):
    plt.scatter(YY[y==i,0],YY[y==i,1],s=20)
plt.grid(0)

# %%
from LE import le
#le(数据集，目标维度，近邻数，sigama值，jump：True(跳过0特征值)or False(保留0特征值))
x_new=le(x,2,10,1,jump=True)
plt.figure(figsize=[5,5])
for i in np.unique(y):
    plt.scatter(x_new[y==i,0],x_new[y==i,1],s=20)
